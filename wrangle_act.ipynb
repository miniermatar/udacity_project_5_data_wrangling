# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Quality-Issues" data-toc-modified-id="Quality-Issues-1">Quality Issues</a></span></li><li><span><a href="#Tidiness" data-toc-modified-id="Tidiness-2">Tidiness</a></span></li></ul></div>

# %%
import pandas as pd
import requests 
import re
import os

# %%
df=pd.read_csv('twitter-archive-enhanced.csv')
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
78+181
2356-259
# Out:
# 2097

# %%
url="https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"

# %%
image_pred_file=requests.get(url)
with open(os.path.join(url.split('/')[-1]),mode='wb') as file:
        file.write(image_pred_file.content)
df_image=pd.read_csv(url.split('/')[-1], sep='\t')
df_image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
image_pred_file=requests.get(url)
with open(os.path.join(url.split('/')[-1]),mode='wb') as file:
        file.write(image_pred_file.content)
df_image=pd.read_csv(url.split('/')[-1], sep='\t')
df_image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df_image.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 1812  833124694597443584  https://pbs.twimg.com/media/C4_ad1IUoAEspsk.jpg
# 2042  885528943205470208  https://pbs.twimg.com/media/DEoH3yvXgAAzQtS.jpg
# 1177  737800304142471168  https://pbs.twimg.com/media/Cj0xdMBVAAEbDHp.jpg
# 1327  757393109802180609  https://pbs.twimg.com/media/CoLNAq6WAAAkmdJ.jpg
# 99    667773195014021121  https://pbs.twimg.com/media/CURoLrOVEAAaWdR.jpg
# 1583  796865951799083009  https://pbs.twimg.com/media/Cw8JWZ2UsAAJOZ6.jpg
# 2067  890729181411237888  https://pbs.twimg.com/media/DFyBahAVwAAhUTd.jpg
# 526   676613908052996102  https://pbs.twimg.com/media/CWPQwmJWUAAu_At.jpg
# 49    666835007768551424  https://pbs.twimg.com/media/CUES51dXIAEahyG.jpg
# 524   676603393314578432  https://pbs.twimg.com/media/CWPHMqKVAAAE78E.jpg
#
#       img_num                           p1   p1_conf  p1_dog  \
# 1812        3                     Cardigan  0.710523    True
# ...

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df[df.tweet_id==676613908052996102]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1815  676613908052996102                    NaN                  NaN
#
#                       timestamp  \
# 1815  2015-12-15 04:05:01 +0000
#
#                                                  source  \
# 1815  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1815  This is the saddest/sweetest/best picture I've...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1815                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1815  https://twitter.com/dog_rates/status/676613908...                12
#
#       rating_denominator name doggo floofer pupper puppo
# 1815                  10  the  None    None   None  None

# %%
df.sample(4)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 477   815990720817401858                    NaN                  NaN
# 1872  675146535592706048                    NaN                  NaN
# 2235  668171859951755264                    NaN                  NaN
# 769   777189768882946048                    NaN                  NaN
#
#                       timestamp  \
# 477   2017-01-02 18:38:42 +0000
# 1872  2015-12-11 02:54:12 +0000
# 2235  2015-11-21 20:59:20 +0000
# 769   2016-09-17 16:57:35 +0000
#
#                                                  source  \
# 477   <a href="http://twitter.com/download/iphone" r...
# 1872  <a href="http://twitter.com/download/iphone" r...
# 2235  <a href="http://twitter.com/download/iphone" r...
# 769   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 477   Meet Jack. He's one of the rare doggos that do...                  NaN
# ...

# %%
df.retweeted_status_id.count()
# Out:
# 181

# %%
df[df.retweeted_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1023  746521445350707200                    NaN                  NaN
# 1043  743835915802583040                    NaN                  NaN
# 1242  711998809858043904                    NaN                  NaN
# 2259  667550904950915073                    NaN                  NaN
# 2260  667550882905632768                    NaN                  NaN
#
#                       timestamp  \
# 19    2017-07-21 01:02:36 +0000
# 32    2017-07-15 02:45:48 +0000
# 36    2017-07-13 01:35:06 +0000
# ...

# %%
df.timestamp.min()
# Out:
# '2015-11-15 22:32:08 +0000'

# %%
df.timestamp.max()
# Out:
# '2017-08-01 16:23:56 +0000'

# %%
df.doggo.value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
df.text.str.contains('doggo',case=False).sum()
# Out:
# 107

# %%
df.floofer.value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
df.text.str.contains('floofer',case=False).sum()
# Out:
# 10

# %%
df.pupper.value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
df.text.str.contains('pupper',case=False).sum()
# Out:
# 283

# %%
df.puppo.value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
df.text.str.contains('puppo',case=False).sum()
# Out:
# 38

# %%
for index, tweet in df[df.rating_denominator>10].iterrows():
    print ("{} - Text: {} - {}/{}".format(index,tweet.text,tweet.rating_numerator,tweet.rating_denominator))
# Out:
# 342 - Text: @docmisterio account started on 11/15/15 - 11/15
# 433 - Text: The floofs have been released I repeat the floofs have been released. 84/70 https://t.co/NIYC820tmd - 84/70
# 784 - Text: RT @dog_rates: After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https:/… - 9/11
# 902 - Text: Why does this never happen at my front door... 165/150 https://t.co/HmwrdfEfUE - 165/150
# 1068 - Text: After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https://t.co/XAVDNDaVgQ - 9/11
# 1120 - Text: Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once https://t.co/yGQI3He3xv - 204/170
# 1165 - Text: Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a - 4/20
# 1202 - Text: This is Bluebert. He just saw that both #FinalFur match ups are split 50/50. Amazed af. 11/10 https://t.co/Kky1DPG4iq - 50/50
# ...

# %%
df[['text','retweeted_status_id']].iloc[1068]
# Out:
# text                   After so many requests, this is Bretagne. She ...
# retweeted_status_id                                                  NaN
# Name: 1068, dtype: object

# %%
df[['text','retweeted_status_id']].iloc[784]
# Out:
# text                   RT @dog_rates: After so many requests, this is...
# retweeted_status_id                                          7.40373e+17
# Name: 784, dtype: object

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
df[df.expanded_urls.isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 185   856330835276025856                    NaN                  NaN
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# 234   847617282490613760           8.476062e+17         4.196984e+09
# ...

# %%
len(str(df.tweet_id[8]))
# Out:
# 18

# %%
for index, tweet in df.iterrows():
    try:
        length=len(str(tweet.tweet_id))
        if length<18:
            print ("{} - lenght: {}".format(index,length))
    except TypeError:
        print ("{} - type error".format(index))
    #else:
     #   print ("{} - error".format(index))

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_image.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Quality Issues

# %% [markdown]
# - Dog stages data type should be categorical
# - Timestamp should be Date/Time data type
# - Fix score for the following tweets:
#     - 784: Score is not accurate since it was confused with 9/11. Correct score is 14/10
#     - 1165 - 4/20 is a date, fix to 13/10
#     - 1202 - should be 11/10 - 50/50 is a split
#     - 1662 - 10/10 instead of 7/11
# - Remove no dogs related tweets: Indexes: 342, 433,1598,1663
# - Adjust missing dog stages:
#     - 10 doggo tweets seems to be missing
#     - 26 floofer
#     - 8 puppo

# %% [markdown]
# ## Tidiness

# %% [markdown]
# - Dog stages should be only one column
# - Remove retweets: Retweets are classified as those records with `retweeted_status_id`

# %% [markdown]
# In reply to must be integer
# expanded url is missing from 59 post
# doggo floofer pupper puppo could be all in one column
# new column type: categorical
# remove retweets
# remove no dogs tweets
# time to date_time
# Updated expanded URL for 59 missing cases
# check expanded URL 734. Repeat

# %% [markdown]
# check:
# 342 need to be removed
# 433
# 784: Score is not accurate since it was confused with 9/11. Correct score is 14/10
# 784 and 1068 seems to be duplicated
# 1165 - 4/20 is a date, fix to 13/10
# 1202 - should be 11/10 - 50/50 is a split
# check 1598
# 1662 - 10/10 instead of 7/11
# check 1663

# %% [markdown]
# Visualization
#
# Retweets - Favorite vs Rating (num/den)
# Type of dog vs rating
# accuracy of algorithms for dog type: match best type with text (lowercase) to see if the algorithm is good.
